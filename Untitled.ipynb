# %%
def get_concat_h(im1, im2):
    #https://note.nkmk.me/en/python-pillow-concat-images/
    dst = Image.new('RGB', (im1.width + im2.width, im1.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    return dst

# %% [markdown]
# # Load Image and Basics

# %%
my_image = "sun.jfif"   ## store image file name variable into a variable otherwise share the image specific path

# %%
import cv2   ## importing opncv libary for interaction with image or video file
image=cv2.imread(my_image)

image.shape  ## image dimension and color channels
# Out:
# (194, 259, 3)

# %%
image.max() ## image maximum pixel intensity value
# Out:
# 255

# %%
image.min()  ## image  minimum pixel instensity value
# Out:
# 0

# %% [markdown]
# # Ploting an Image

# %%
import matplotlib.pyplot as plt
import cv2
image=cv2.imread(my_image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
